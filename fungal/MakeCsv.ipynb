# %%
import csv

with open('/Users/Sonia/Downloads/1471-2164-5-57-S1.csv') as csvfile:
    
    csvReader = csvfile.readlines()
    
    with open('SepCsvData.csv', 'w') as outFile:
        
        write_outfile = csv.writer(outFile)
    
        for line in csvReader:
            currentline = line.split(';')
            
            print(currentline)
            write_outfile.writerow(currentline)
# Out:
# ['AccNo', 'Mean CBA', 'Mean BL10', 'Mean BL6', 'Mean DBA', 'Mean BALB', 'FDR 10%', 'FDR 15%', 'FDR 20%', 'UniGeneID', 'Description', 'GOnumber', 'CBA', 'BL10', 'BL6', 'DBA', 'BALB', '', 'MEAN CBA', 'MEAN BL10', 'MEAN BL6', 'MEAN DBA', 'MEAN BALB\n']
# ['AB001456', '2.47', '2.36', '1.86', '2.45', '2.53', '1', '1', '1', 'MM.90223', 'Mus musculus mRNA for motor domain of KIF1C, partial cds', 'microtubule-based process [0007017]', '0.136803746', '0.02639665', '-0.475588707', '0.119624073', '0.192764238', '', '2.47', '2.36', '1.86', '2.45', '2.53\n']
# ['AB010370', '0.75', '1.05', '0.61', '0.69', '1.10', '1', '1', '1', '', 'Mus musculus mRNA for mszf80-2, partial cds', 'transcription regulation [0006355]', '-0.089020895', '0.21204956', '-0.229818608', '-0.151372743', '0.258162686', '', '0.75', '1.05', '0.61', '0.69', '1.10\n']
# ...
