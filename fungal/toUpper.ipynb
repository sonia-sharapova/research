# %%
"""
                if "frameshift_variant" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (2)")
                if "missense_variant" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (3)")
                
                
                
"""
import csv
mutList = []

#st.norm.cdf(-0.45839643946529063)

with open('/Users/soniasharapova/Documents/JunDingResearch/pythonFiles/cdfMutationsfsMissOnly.csv', 'r') as mutations:
    genes = csv.reader(mutations)
    next(genes) 
    
    with open('/Users/soniasharapova/Documents/JunDingResearch/pythonFiles/cdfMutationsfsMissOnlyUpper.csv', 'w') as outFileMuts:
        write_outfile_muts = csv.writer(outFileMuts)

        mutList.append("Gene")
        mutList.append("Mutation CDF")
        write_outfile_muts.writerow(mutList)
    
        mutList = []
        
        
        #cdf
        for line in genes:
            gene = line[0]
            #print(zscore)
            #cdf = st.norm.cdf(float(zscore))
            upper = gene.upper()

            mutList.append(upper)
            mutList.append(line[1])
            
            write_outfile_muts.writerow(mutList)
            print(mutList)
            mutList = []
# Out:
# ['G', '0.5']
# ['2300002M23RIK', '0.5322286020866925']
# ['2310061I04RIK', '0.5322286020866925']
# ['4833413E03RIK', '0.5322286020866925']
# ['4921501E09RIK', '0.9154101472361788']
# ['4930539E08RIK', '0.5642472157888833']
# ['ACTL9', '0.5642472157888833']
# ['AGER', '0.5322286020866925']
# ['ATF6B', '0.5322286020866925']
# ['BC051142', '0.5322286020866925']
# ['BRD4', '0.5322286020866925']
# ['BTBD9', '0.5642472157888833']
# ['BTNL1', '0.5642472157888833']
# ['BTNL2', '0.6570281952427544']
# ['BTNL4', '0.9999956668445749']
# ['BTNL6', '0.9999999879913846']
# ['C4B', '0.6570281952427544']
# ['CBS', '0.5322286020866925']
# ['COL11A2', '0.6862466543856541']
# ['CPNE5', '0.5322286020866925']
# ['CYP21A1', '0.714341305648531']
# ['CYP4F13', '0.6570281952427544']
# ['CYP4F15', '0.5322286020866925']
# ['CYP4F17', '0.5322286020866925']
# ['DAXX', '0.5322286020866925']
# ['DNAH8', '0.5322286020866925']
# ['EPHX3', '0.5322286020866925']
# ['ESP31', '0.5958499484021504']
# ...
