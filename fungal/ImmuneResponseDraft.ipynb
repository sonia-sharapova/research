# %%
#mergedUniqueGenes.csv
import csv
from csv import reader
from copy import deepcopy

binFile = []
completeFile = []
binary = 0

with open('/Users/Sonia/mergedUniqueGenes.csv', 'r') as read_genes, open('/Users/Sonia/GO_term_summary_20210719_142850.csv', 'r') as read_immunegenes:
    geneFiles = reader(read_genes)
    immuneGenes = reader(read_immunegenes)
    
    for line in geneFiles:
        #print(line[0].lower())
        gene = line[0].lower()
        print(gene)
        binFile.append(gene)
        for row in immuneGenes:
            imGene = row[1].lower()
            #print(gene)
            print(imGene)
                
            if imGene == gene:
                print("Same")
                binary = 1
            
        if binary == 1:
            binFile.append(1)
            #print(gene)
            #print(binary)
        else:
            binFile.append(0)
            #print(line[0])
            #print(binary)
        completeFile.append(binFile)
        print(binFile)
        binFile = []
        immuneGenes = reader(read_immunegenes)
            
#print(completeFile)
# Out:
# gene
# symbol
# 1300017j02rik
# 1810058i24rik
# 1810058i24rik
# 2610528a11rik
# 2610528a11rik
# 2610528a11rik
# 2610528a11rik
# 2610528a11rik
# 2610528a11rik
# 3830403n18rik
# 4930430f08rik
# 4930474n05rik
# 4930486l24rik
# 6030468b19rik
# 6030468b19rik
# 6030468b19rik
# 6030468b19rik
# 6030468b19rik
# 9230019h11rik
# 9230019h11rik
# 9530003j23rik
# 9530003j23rik
# 9530003j23rik
# 9530003j23rik
# a2m
# abca15
# abcb9
# abcb10
# abcb10
# abcc9
# abcf3
# abi1
# abl1
# abl1
# abl1
# abl1
# abl1
# abl1
# abl1
# abl1
# abl1
# abl1
# abl1
# abl1
# abl1
# abl1
# abl2
# abr
# abr
# ace
# ace
# ackr2
# ackr3
# ackr4
# acod1
# acod1
# acod1
# acod1
# acod1
# acod1
# acod1
# acod1
# acod1
# acod1
# acod1
# acp5
# acp6
# actg1
# actn1
# actr2
# actr3
# acvr1b
# acvr2a
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# ada
# adam8
# adam8
# adam8
# adam8
# adam8
# adam8
# adam8
# adam8
# adam8
# adam8
# adam8
# adam8
# adam9
# ...
