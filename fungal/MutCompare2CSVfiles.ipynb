# %%
import csv
#reader1 = csv.reader(open('/Users/Sonia/Downloads/prox_C57BL-6NJ_SNPs_rel-1505-snps-export-17_28802208-32242276.csv', 'r'), delimiter=',', quotechar='"')
#row1 = next(reader1)
#reader2 = csv.reader(open('/Users/Sonia/Downloads/prox_CBA-J_SNPs_rel-1505-snps-export-17_28802208-32242276.csv', 'r'), delimiter=',', quotechar='"')
#row2 = next(reader2)
    
from csv import reader
from copy import deepcopy

fullList = []
mutList = []
newList = []
prevGene = ""
chrompos = ""
    
with open('/Users/Sonia/Work/JunDingResearch/csvs/mutations/fullMutations/fullMutsCombined.csv', 'r') as read_obj:
    csv_reader = reader(read_obj)
    
    for row in csv_reader:
        
        mutList.append(row[2])  
        
        if row[3] == "-":
            
            if "coding_sequence_variant" in row[6] or "coding_sequence_variant" in row[8]:
                chrompos = row[0] + "," + row[1]
                mutList.append(chrompos + " (1)")
            if "frameshift_variant" in row[6] or "frameshift_variant" in row[8]:
                chrompos = row[0] + "," + row[1]
                mutList.append(chrompos + " (2)")
            if "missense_variant" in row[6] or "missense_variant" in row[8]:
                chrompos = row[0] + "," + row[1]
                mutList.append(chrompos + " (3)")
            if "splice_acceptor_variant" in row[6] or "splice_acceptor_variant" in row[8]:
                chrompos = row[0] + "," + row[1]
                mutList.append(chrompos + " (4)")
            if "splice_donor_variant" in row[6] or "splice_donor_variant" in row[8]:
                chrompos = row[0] + "," + row[1]
                mutList.append(chrompos + " (5)")
            if "splice_region_variant" in row[6] or "splice_region_variant" in row[8]:
                chrompos = row[0] + "," + row[1]
                mutList.append(chrompos + " (6)")
            if "TF_binding_site_variant" in row[6] or "TF_binding_site_variant" in row[8]:
                chrompos = row[0] + "," + row[1]
                mutList.append(chrompos + " (7)")
            if "TFBS_ablation" in row[6] or "TFBS_ablation" in row[8]:
                chrompos = row[0] + "," + row[1]
                mutList.append(chrompos + " (8)")
            if "TFBS" in row[6] or "TFBS" in row[8]:
                chrompos = row[0] + "," + row[1]
                mutList.append(chrompos + " (9)")
            if "upstream_gene_variant" in row[6] or "upstream_gene_variant" in row[8]:
                chrompos = row[0] + "," + row[1]
                mutList.append(chrompos + " (10)")
                
                
                
        elif row[3] != "-":
            
            if "coding_sequence_variant" in row[6] or "coding_sequence_variant" in row[8]:
                mutList.append(row[3] + " (1)")
            if "frameshift_variant" in row[6] or "frameshift_variant" in row[8]:
                mutList.append(row[3] + " (2)")
            if "missense_variant" in row[6] or "missense_variant" in row[8]:
                mutList.append(row[3] + " (3)")
            if "splice_acceptor_variant" in row[6] or "splice_acceptor_variant" in row[8]:
                mutList.append(row[3] + " (4)")
            if "splice_donor_variant" in row[6] or "splice_donor_variant" in row[8]:
                mutList.append(row[3] + " (5)")
            if "splice_region_variant" in row[6] or "splice_region_variant" in row[8]:
                mutList.append(row[3] + " (6)")
            if "TF_binding_site_variant" in row[6] or "TF_binding_site_variant" in row[8]:
                mutList.append(row[3] + " (7)")
            if "TFBS_ablation" in row[6] or "TFBS_ablation" in row[8]:
                mutList.append(row[3] + " (8)")
            if "TFBS" in row[6] or "TFBS" in row[8]:
                mutList.append(row[3] + " (9)")
            if "upstream_gene_variant" in row[6] or "upstream_gene_variant" in row[8]:
                mutList.append(row[3] + " (10)")
            
            
        #newMutList = deepcopy(mutList)
        #print(mutList)
        fullList.append(mutList[:])
        #print(fullList)
        #newMutList = deepcopy(fullList)
        #print(fullList)
        mutList.clear()
        #print(newMutList)
        #newList.append(fullList)
        #print(newList)
        
    #print(fullList)
    #newMutList = deepcopy(fullList)
        
    with open('allMutations.csv', 'w') as outFile:
        write = csv.writer(outFile)
        write.writerows(fullList)

"""
with open('/Users/Sonia/Work/JunDingResearch/csvs/mutations/full-all-CBA-J/full-all-combined-CBA-J.csv', 'r') as read_obj:
    csv_reader2 = reader(read_obj)
    fullList2 = []
    mutList2 = []
    prevGene2 = ""
    
    for row2 in csv_reader2:
        
        if row2[3] != "-":
            mutList2.append(row2[2])
            
            if "coding_sequence_variant" in row2[6]:
                mutList2.append(row2[3] + " (1)")
            if "frameshift_variant" in row2[6]:
                mutList2.append(row2[3] + " (2)")
            if "missense_variant" in row2[6]:
                mutList2.append(row2[3] + " (3)")
            if "splice_acceptor_variant" in row2[6]:
                mutList2.append(row2[3] + " (4)")
            if "splice_donor_variant" in row2[6]:
                mutList2.append(row2[3] + " (5)")
            if "splice_region_variant" in row2[6]:
                mutList2.append(row2[3] + " (6)")
            if "TF_binding_site_variant" in row2[6]:
                mutList2.append(row2[3] + " (7)")
            if "TFBS_ablation" in row2[6]:
                mutList2.append(row2[3] + " (8)")
            if "TFBS" in row2[6]:
                mutList2.append(row2[3] + " (9)")
            if "upstream_gene_variant" in row2[6]:
                mutList2.append(row2[3] + " (10)")
            
            
            newMutList2 = deepcopy(mutList2)
            
            if row2[2] == prevGene2:
                
                listLen2 = len(fullList2)
                
                if "coding_sequence_variant" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (1)")
                if "frameshift_variant" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (2)")
                if "missense_variant" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (3)")
                if "splice_acceptor_variant" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (4)")
                if "splice_donor_variant" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (5)")
                if "splice_region_variant" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (6)")
                if "TF_binding_site_variant" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (7)")
                if "TFBS_ablation" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (8)")
                if "TFBS" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (9)")
                if "upstream_gene_variant" in row2[6]:
                    fullList2[listLen2 - 1].append(row2[3] + " (10)")
                
                                
            else:
                fullList2.append(newMutList2)
            
            prevGene2 = row2[2]
            
        mutList2.clear()
        
    print(fullList2)
    



with open('/Users/Sonia/Downloads/fullList1.csv', 'w') as f1:
      
    write1 = csv.writer(f1)
    write1.writerows(fullList1)
    
#with open('/Users/Sonia/Downloads/fullList2.csv', 'w') as f2:
      
    #write2 = csv.writer(f2) 
    #write2.writerows(fullList2)
    
   

    
with open('/Users/Sonia/Downloads/fullList1.csv', 'r') as t1, open('/Users/Sonia/Downloads/fullList2.csv', 'r') as t2:
    fileone = t1.readlines()
    filetwo = t2.readlines()


with open('/Users/Sonia/Downloads/fullList1.csv', 'w') as f1:
      
    write1 = csv.writer(f1)
    write1.writerows(fullList1)
    
with open('/Users/Sonia/Downloads/fullList1.csv', 'r') as t1:
    fileone = t1.readlines()
"""
# Out:
# '\nwith open(\'/Users/Sonia/Work/JunDingResearch/csvs/mutations/full-all-CBA-J/full-all-combined-CBA-J.csv\', \'r\') as read_obj:\n    csv_reader2 = reader(read_obj)\n    fullList2 = []\n    mutList2 = []\n    prevGene2 = ""\n    \n    for row2 in csv_reader2:\n        \n        if row2[3] != "-":\n            mutList2.append(row2[2])\n            \n            if "coding_sequence_variant" in row2[6]:\n                mutList2.append(row2[3] + " (1)")\n            if "frameshift_variant" in row2[6]:\n                mutList2.append(row2[3] + " (2)")\n            if "missense_variant" in row2[6]:\n                mutList2.append(row2[3] + " (3)")\n            if "splice_acceptor_variant" in row2[6]:\n                mutList2.append(row2[3] + " (4)")\n            if "splice_donor_variant" in row2[6]:\n                mutList2.append(row2[3] + " (5)")\n            if "splice_region_variant" in row2[6]:\n                mutList2.append(row2[3] + " (6)")\n            if "TF_binding_site_v
# ...
