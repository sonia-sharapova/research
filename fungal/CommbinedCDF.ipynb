# %%
import csv

fullScoreList = []
newRow = []
count = 0

with open('/Users/Sonia/CDFregionalFeature3final.csv', 'r') as fullGenes:
    allGenes = fullGenes.readlines()
    
    with open('/Users/Sonia/Work/JunDingResearch/cdfs/GenesInRegion/SPathsCDFregional.csv', 'r') as Mutations:
        mut = Mutations.readlines()
    
        
        for gene in allGenes:
            gene.rstrip('\r\n')
            el = gene.split(',')
            for y in el:
                newRow.append(y.rstrip('\r\n').strip('\"'))
                
            
            
            if newRow != ['']:
                #print(newRow)
                
                
                for pth in mut:
                    pthEl = pth.split(',')
                
                    if pthEl[0] == newRow[0]:
                        #print(newRow[0])
                        #print(pthEl[0])
                        #print(gene)
                        
                        newRow.append(pthEl[1].strip('\r\n').strip('\"'))
                        print(newRow)
                        count = 1
                        
                        
                #print(count)
                if count == 0:
                    newRow.append(0)
                #newRow[1].strip('\r\n')
                #print(newRow)
                fullScoreList.append(newRow)
        
                newRow = []    
            count = 0
                     
            #print(newRow)
        
#print(fullScoreList)

with open('/Users/Sonia/CDFregionalFeature4final.csv', 'w') as outFile:
        write = csv.writer(outFile)
        write.writerows(fullScoreList)


    
    #for x in fullScoreList:
        #x = str(x)
        #print(x)
        #outFile.write(x)
# Out:
# ['FGD2', '1', '0.9999234516982959', '0.5751118887734545', '0.8812045652342784']
# ['PI16', '0', '0.5609043995679992', '0.850123012356998', '0.647840055641882']
# ['RSPH1', '1', '0.47632273618412513', '0.7706128110624114', '0.9440184391084865']
# ['PPIL1', '0', '0.9478200967737571', '0.8990601312841822', '0.23640669992794172']
# ['GLO1', '1', '0.4202906297149081', '0.9999999999998336', '0.4967781956219247']
# ['PKNOX1', '1', '0.3860025302658909', '0.9095168008375905', '0.5529307335525284']
# ['TRIM26', '1', '0.4622264192590154', '0.921175294038489', '0.456352585856924']
# ['VARS2', '0', '0.4202906297149081', '0.6635799712235491', '0.9301487975979021']
# ['ABCG1', '1', '0.3860025302658909', '0.6734824584460775', '0.9301487975979021']
# ['MYO1F', '1', '0.5955579036463504', '0.4243997637175738', '0.7736734879742404']
# ['HSF2BP', '0', '0.5116547056390022', '0.47481770019666214', '0.9885715124089715']
# ['CDKN1A', '1', '0.9260331453775421', '0.9674925233006724', '0.08593204834126311']
# ...
