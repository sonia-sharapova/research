# %%
import csv
import pandas as pd
import math

mutList = []
mutElNum = 0
mutNumRows = 0
mutGrandSum = 0
headerCheck = 0
mutGrandSumData = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
count8 = 0
count9 = 0
count10 = 0
weightSum = 24

with open('/Users/Sonia/CombinedMutationsAll.csv', 'r') as mutationMean:
    mutMean = csv.reader(mutationMean)
    next(mutMean)
    #mean
    for line in mutMean:
            #el = line.split(',')
            #print(line)
        mutNumRows = mutNumRows + 1
        for x in line:
        
            if headerCheck != 0 and x != "\n" and x != '':
                count = x[x.find('(')+1:x.find(')')]
                #print(count)
                if count == "1":
                    count1 = count1 + 1
                if count == "2":
                    count2 = count2 + 1
                if count == "3":
                    count3 = count3 + 1
                if count == "4":
                    count4 = count4 + 1
                if count == "5":
                    count5 = count5 + 1
                if count == "6":
                    count6 = count6 + 1
                if count == "7":
                    count7 = count7 + 1
                if count == "8":
                    count8 = count8 + 1
                if count == "9":
                    count9 = count9 + 1
                if count == "10":
                    count10 = count10 + 1
                
            headerCheck = 1
            
        weightedSum = (count1*5)+(count2*1)+(count3*5)+(count4*1)+(count5*1)+(count6*1)+(count7*3)+(count8*3)+(count9*3)+(count10*1)
        mutGrandSum = mutGrandSum + weightedSum
        #print(mutGrandSum)
        #mutGrandSum = mutGrandSum + mutElNum 
            
        headerCheck = 0
        weightedSum = 0
        count1 = 0
        count2 = 0
        count3 = 0
        count4 = 0
        count5 = 0
        count6 = 0
        count7 = 0
        count8 = 0
        count9 = 0
        count10 = 0
            
    #meanMut = mutGrandSum / mutNumRows
    
    weightMean = mutGrandSum / mutNumRows
    #print(mutGrandSum)
    #print(mutNumRows)
    print(weightMean)

            

with open('/Users/Sonia/CombinedMutationsAll.csv', 'r') as mutationsStd:
    mutStd = csv.reader(mutationsStd)
    next(mutStd) 
    
    #std
    for line in mutStd:
        for x in line:
            if headerCheck != 0 and x != "\n" and x != '':
                count = x[x.find('(')+1:x.find(')')]

                if count == "1":
                    count1 = count1 + 1
                if count == "2":
                    count2 = count2 + 1
                if count == "3":
                    count3 = count3 + 1
                if count == "4":
                    count4 = count4 + 1
                if count == "5":
                    count5 = count5 + 1
                if count == "6":
                    count6 = count6 + 1
                if count == "7":
                    count7 = count7 + 1
                if count == "8":
                    count8 = count8 + 1
                if count == "9":
                    count9 = count9 + 1
                if count == "10":
                    count10 = count10 + 1
                
            headerCheck = 1
             
        weightedSum = (count1*5)+(count2*1)+(count3*5)+(count4*1)+(count5*1)+(count6*1)+(count7*3)+(count8*3)+(count9*3)+(count10*1)
        dataPoint = (weightedSum - weightMean)**2
        #print(dataPoint)
        #print(pathElNum)
        mutGrandSumData = mutGrandSumData + dataPoint
        #print(pathGrandSumData)
        dataPoint = 0
        headerCheck = 0
        weightedSum = 0
        count1 = 0
        count2 = 0
        count3 = 0
        count4 = 0
        count5 = 0
        count6 = 0
        count7 = 0
        count8 = 0
        count9 = 0
        count10 = 0       
                
    print(mutNumRows)
    stdMut = math.sqrt(mutGrandSumData / mutNumRows)
    print(stdMut)
        

with open('/Users/Sonia/CombinedMutationsAll.csv', 'r') as mutationsZScore:
    mutZS = csv.reader(mutationsZScore)
    next(mutZS)  
    
    with open('zScoresCombinedMutations.csv', 'w') as outFileMuts:
    
        write_outfile_muts = csv.writer(outFileMuts)

        mutList.append("Gene")
        mutList.append("Mutation Z-Score")
        write_outfile_muts.writerow(mutList)
    
        mutList = []
        
        
        #z-score
        for line in mutZS:
            for x in line:
                if headerCheck != 0 and x != "\n" and x != '':
                    count = x[x.find('(')+1:x.find(')')]

                    if count == "1":
                        count1 = count1 + 1
                    if count == "2":
                        count2 = count2 + 1
                    if count == "3":
                        count3 = count3 + 1
                    if count == "4":
                        count4 = count4 + 1
                    if count == "5":
                        count5 = count5 + 1
                    if count == "6":
                        count6 = count6 + 1
                    if count == "7":
                        count7 = count7 + 1
                    if count == "8":
                        count8 = count8 + 1
                    if count == "9":
                        count9 = count9 + 1
                    if count == "10":
                        count10 = count10 + 1
                
                headerCheck = 1
            weightedSum = (count1*5)+(count2*1)+(count3*5)+(count4*1)+(count5*1)+(count6*1)+(count7*3)+(count8*3)+(count9*3)+(count10*1)
        
            
            ZScore = (weightedSum  - meanMut ) / stdMut
            weightedSum = 0
            headerCheck = 0
            count1 = 0
            count2 = 0
            count3 = 0
            count4 = 0
            count5 = 0
            count6 = 0
            count7 = 0
            count8 = 0
            count9 = 0
            count10 = 0   
        
            mutList.append(line[0])
            mutList.append(ZScore)

            print(mutList)
            write_outfile_muts.writerow(mutList)
            mutList = []
# Out:
# 25.17167381974249
# 466
# 56.431398325230305
# ['2-Mar', 0.7203227897266781]
# ['1110038B12Rik', -0.36063571582796966]
# ['1700030A11Rik', 0.5962783710564726]
# ['1700031A10Rik', -0.30747382211216734]
# ['1700097N02Rik', -0.041664353533155604]
# ['2300002M23Rik', -0.09482624724895795]
# ['2310061I04Rik', -0.2365912971577642]
# ['2410017I17Rik', -0.3429150845893689]
# ['2410137M14Rik', -0.3429150845893689]
# ['4833413E03Rik', -0.25431192839636496]
# ['4833427F10Rik', -0.28975319087356655]
# ['4921501E09Rik', 1.6772368766111203]
# ['4930539E08Rik', 0.11782132761425144]
# ['4931413I07Rik', -0.32519445335076813]
# ['A930015D03Rik', -0.36063571582796966]
# ['Abcf1', -0.30747382211216734]
# ['Abcg1', -0.28975319087356655]
# ['Abhd16a', -0.041664353533155604]
# ['Actl9', 0.13554195885285222]
# ['Adamts10', 1.3228242518391047]
# ['Ager', -0.13026750972615952]
# ['Agpat1', -0.30747382211216734]
# ['Aif1', -0.20115003468056264]
# ['Akap8', -0.36063571582796966]
# ['Akap8l', -0.3429150845893689]
# ['Angptl4', -0.07710561601035716]
# ['Apom', -0.27203255963496575]
# ['Atat1', -0.27203255963496575]
# ['Atf6b', -0.07710561601035716]
# ['Atp6v1g2', -0.2365912971577642]
# ['H2-M10.1', -0.32519445335076813]
# ['H2-M10.2', -0.30747382211216734]
# ['H2-M10.3', -0.3429150845893689]
# ['H2-M10.4', -0.2365912971577642]
# ['H2-M10.5', -0.21887066591916343]
# ['H2-M10.6', -0.2365912971577642]
# ['H2-M11', -0.21887066591916343]
# ['H2-M2', -0.32519445335076813]
# ['H2-M3', -0.3429150845893689]
# ['H2-M5', -0.30747382211216734]
# ['H2-M6-ps', -0.3429150845893689]
# ['H2-M9', -0.30747382211216734]
# ['H2-Oa', 1.1810592019302983]
# ['H2-Ob', 1.3582655143163063]
# ['H2-Pa', 0.649440264772275]
# ['H2-Pb', 0.4190720586704647]
# ['H2-Q1', -0.20115003468056264]
# ['H2-Q10', -0.3429150845893689]
# ['H2-Q2', -0.20115003468056264]
# ['H2-Q3', -0.27203255963496575]
# ['H2-Q4', -0.2365912971577642]
# ['H2-Q5', -0.27203255963496575]
# ['H2-T10', -0.36063571582796966]
# ['H2-T22', -0.36063571582796966]
# ['H2-T23', -0.30747382211216734]
# ['H2-T3', -0.3429150845893689]
# ['Hnrnpm', 0.10010069637565065]
# ['Hsf2bp', 0.029218171421247528]
# ['Hspa1a', -0.36063571582796966]
# ['Hspa1b', -0.36063571582796966]
# ['Ier3', -0.36063571582796966]
# ['Kank3', -0.3429150845893689]
# ['Kctd20', -0.30747382211216734]
# ['Kifc1', 1.1101766769758954]
# ['Lsm2', -0.36063571582796966]
# ['Lst1', -0.02394372229455482]
# ['Lta', -0.13026750972615952]
# ['Ltb', -0.32519445335076813]
# ['Ly6g5b', -0.36063571582796966]
# ['Ly6g5c', -0.25431192839636496]
# ['Ly6g6c', -0.30747382211216734]
# ['Ly6g6d', -0.16570877220336108]
# ['Ly6g6e', -0.27203255963496575]
# ['Mdc1', -0.32519445335076813]
# ['Mdga1', 0.04693880265984831]
# ['Mir6970', -0.36063571582796966]
# ['Mir6971', -0.36063571582796966]
# ['Mir6974', -0.36063571582796966]
# ['Mir7667', 0.3481895337160616]
# ['Mir8094', -0.3429150845893689]
# ['Mog', -0.30747382211216734]
# ['Morc2b', 0.029218171421247528]
# ['Msh5', -0.041664353533155604]
# ['Mtch1', 0.3836307961932632]
# ['Myo1f', 0.24186574628445692]
# ['Ndufa7', -0.30747382211216734]
# ['Ndufv3', -0.27203255963496575]
# ['Nelfe', -0.3429150845893689]
# ['Nfkbil1', -0.18342940344196185]
# ['Notch3', 0.11782132761425144]
# ['Notch4', 2.013928870144535]
# ['Nrm', -0.2365912971577642]
# ['Olfr102', -0.36063571582796966]
# ['Olfr103', -0.30747382211216734]
# ['Olfr104-ps', -0.36063571582796966]
# ['Olfr105-ps', -0.30747382211216734]
# ['Olfr106-ps', -0.1479881409647603]
# ['Olfr107', -0.32519445335076813]
# ['Olfr108', -0.36063571582796966]
# ['Olfr109', -0.36063571582796966]
# ['Olfr111', -0.25431192839636496]
# ['Olfr112', -0.30747382211216734]
# ['Rnf5', -0.36063571582796966]
# ['Rnf8', -0.13026750972615952]
# ['RP23-106N22.5', -0.32519445335076813]
# ['RP23-364A24.1', -0.11254687848755873]
# ['RP23-98F21.12', -0.13026750972615952]
# ['Rpl35a-ps3', -0.32519445335076813]
# ['Rpl9-ps5', -0.36063571582796966]
# ['Rpp21', -0.36063571582796966]
# ['Rps18', 0.13554195885285222]
# ['Rrp1b', 0.2950276400002593]
# ['Rsph1', -0.05938498477175638]
# ['Rxrb', -0.28975319087356655]
# ['Sapcd1', 0.029218171421247528]
# ['Sik1', -0.13026750972615952]
# ['Skiv2l', -0.36063571582796966]
# ['Skiv2l-ps1', -0.32519445335076813]
# ['Slc37a1', -0.07710561601035716]
# ['Slc39a7', -0.18342940344196185]
# ['Slc44a4', -0.3429150845893689]
# ['Srsf3', -0.18342940344196185]
# ['Stk19', -0.09482624724895795]
# ['Stk19-ps1', -0.041664353533155604]
# ['Stk38', -0.07710561601035716]
# ['Tap1', 0.5431164773406703]
# ['Tap2', 0.808925945919682]
# ['Tapbp', 0.029218171421247528]
# ['Tbc1d22b', -0.16570877220336108]
# ['Tbc1d22bos', -0.13026750972615952]
# ['Tff1', -0.2365912971577642]
# ['Tff3', -0.36063571582796966]
# ['Tmem217', -0.3429150845893689]
# ['Tmprss3', -0.09482624724895795]
# ['Tnf', -0.3429150845893689]
# ['Tnxa', 0.13554195885285222]
# ['Tnxb', 1.8898844514743298]
# ['Trim10', -0.20115003468056264]
# ['Trim15', -0.32519445335076813]
# ['Trim26', -0.09482624724895795]
# ['Trim31', -0.11254687848755873]
# ['Trim39', -0.36063571582796966]
# ['Trim40', -0.21887066591916343]
# ['Trp53cor1', 0.7557640522038797]
# ['U2af1', -0.28975319087356655]
# ['Ubash3a', 0.31274827123886006]
# ['Ubd', -0.27203255963496575]
# ['Umodl1', 0.8443672083968836]
# ['Vars', -0.36063571582796966]
# ['Vars2', -0.20115003468056264]
# ['Vhl-ps1', -0.36063571582796966]
# ['Vps52', 2.7404747509271674]
# ['Wdr4', -0.28975319087356655]
# ['Wdr46', 0.6848815272494765]
# ['Wiz', -0.09482624724895795]
# ['Zbtb12', -0.36063571582796966]
# ['Zbtb22', -0.36063571582796966]
# ['Zfand3', -0.2365912971577642]
# ['Zfp101', -0.09482624724895795]
# ['Zfp414', -0.36063571582796966]
# ['Zfp422-rs1', 0.10010069637565065]
# ['Zfp472', 0.13554195885285222]
# ['Zfp563', 0.4190720586704647]
# ['Zfp57', -0.32519445335076813]
# ['Zfp763', -0.041664353533155604]
# ['Zfp799', -0.13026750972615952]
# ['Zfp81', 0.17098322133005378]
# ['Zfp811', -0.28975319087356655]
# ['Zfp870', 1.2165004644075]
# ['Zfp871', -0.16570877220336108]
# ['Zfp952', -0.13026750972615952]
# ['Zfp955a', 0.3304689024774608]
# ['Zfp955b', 0.22414511504585613]
# ['Znrd1', -0.3429150845893689]
